# %%
# docs and experiment results can be found at https://docs.cleanrl.dev/rl-algorithms/dqn/#dqnpy
import os
import random
import time
from dataclasses import dataclass

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tyro
from stable_baselines3.common.buffers import ReplayBuffer
from torch.utils.tensorboard import SummaryWriter


@dataclass
class Args:
    exp_name: str = "baseline_dqn"
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: bool = True
    """if toggled, cuda will be enabled by default"""
    track: bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "cleanRL"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""
    save_model: bool = False
    """whether to save model into the `runs/{run_name}` folder"""
    upload_model: bool = False
    """whether to upload the saved model to huggingface"""
    hf_entity: str = ""
    """the user or org name of the model repository from the Hugging Face Hub"""

    # Algorithm specific arguments
    env_id: str = "CartPole-v1"
    """the id of the environment"""
    total_timesteps: int = 500000
    """total timesteps of the experiments"""
    learning_rate: float = 2.5e-4
    """the learning rate of the optimizer"""
    num_envs: int = 1
    """the number of parallel game environments"""
    buffer_size: int = 10000
    """the replay memory buffer size"""
    gamma: float = 0.99
    """the discount factor gamma"""
    tau: float = 1.0
    """the target network update rate"""
    target_network_frequency: int = 500
    """the timesteps it takes to update the target network"""
    batch_size: int = 128
    """the batch size of sample from the reply memory"""
    start_e: float = 1
    """the starting epsilon for exploration"""
    end_e: float = 0.05
    """the ending epsilon for exploration"""
    exploration_fraction: float = 0.5
    """the fraction of `total-timesteps` it takes from start-e to go end-e"""
    learning_starts: int = 10000
    """timestep to start learning"""
    train_frequency: int = 10
    """the frequency of training"""


def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        env.action_space.seed(seed)

        return env

    return thunk


# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(np.array(env.single_observation_space.shape).prod(), 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, env.single_action_space.n),
        )

    def forward(self, x):
        return self.network(x)


def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

# %%
import stable_baselines3 as sb3

if sb3.__version__ < "2.0":
    raise ValueError(
        """Ongoing migration: run the following command to install the new dependencies:

poetry run pip install "stable_baselines3==2.0.0a1"
"""
    )

args = Args()

# %%
assert args.num_envs == 1, "vectorized envs are not supported at the moment"
run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
if args.track:
    import wandb

    wandb.init(
        project=args.wandb_project_name,
        entity=args.wandb_entity,
        sync_tensorboard=True,
        config=vars(args),
        name=run_name,
        monitor_gym=True,
        save_code=True,
    )
writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# TRY NOT TO MODIFY: seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

# %%
# env setup
envs = gym.vector.SyncVectorEnv(
    [make_env(8, args.seed)]
)
assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"

q_network = QNetwork(envs).to(device)
optimizer = optim.Adam(q_network.parameters(), lr=args.learning_rate)
target_network = QNetwork(envs).to(device)
target_network.load_state_dict(q_network.state_dict())

rb = ReplayBuffer(
    args.buffer_size,
    envs.single_observation_space,
    envs.single_action_space,
    device,
    handle_timeout_termination=False,
)
start_time = time.time()
# Out:
# /Users/atticusw/opt/anaconda3/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.get_frame to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_frame` for environment variables or `env.get_wrapper_attr('get_frame')` that will search the reminding wrappers.
#   logger.warn(
# /Users/atticusw/opt/anaconda3/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.highlight to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.highlight` for environment variables or `env.get_wrapper_attr('highlight')` that will search the reminding wrappers.
#   logger.warn(
# /Users/atticusw/opt/anaconda3/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.tile_size to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.tile_size` for environment variables or `env.get_wrapper_attr('tile_size')` that will search the reminding wrappers.
#   logger.warn(
# /Users/atticusw/opt/anaconda3/lib/python3.9/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.agent_pov to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.agent_pov` for environment variables or `env.get_wrapper_attr('agent_pov')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/8m/r3kmm3xs1lngf9bhwg216mlc0000gn/T/ipykernel_38286/191038067.py in <module>
#       1 # env setup
# ----> 2 envs = gym.vector.SyncVectorEnv(
#       3     [make_env(8, args.seed)]
#       4 )
#       5 assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gym/vector/sync_vector_env.py in __init__(self, env_fns, observation_space, action_space, copy)
#      57             observation_space = observation_space or self.envs[0].observation_space
#      58             action_space = action_space or self.envs[0].action_space
# ---> 59         super().__init__(
#      60             num_envs=len(self.envs),
#      61             observation_space=observation_space,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gym/vector/vector_env.py in __init__(self, num_envs, observation_space, action_space)
#      38         self.num_envs = num_envs
#      39         self.is_vector_env = True
# ---> 40         self.observation_space = batch_space(observation_space, n=num_envs)
#      41         self.action_space = batch_space(action_space, n=num_envs)
#      42
#
# ~/opt/anaconda3/lib/python3.9/functools.py in wrapper(*args, **kw)
#     875                             '1 positional argument')
#     876
# --> 877         return dispatch(args[0].__class__)(*args, **kw)
#     878
#     879     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gym/vector/utils/spaces.py in batch_space(space, n)
#      39         ValueError: Cannot batch space that is not a valid :class:`gym.Space` instance
#      40     """
# ---> 41     raise ValueError(
#      42         f"Cannot batch space with type `{type(space)}`. The space must be a valid `gym.Space` instance."
#      43     )
#
# ValueError: Cannot batch space with type `<class 'gymnasium.spaces.box.Box'>`. The space must be a valid `gym.Space` instance.

# %%
import torch
import torch.nn as nn
from torch.distributions.categorical import Categorical
import torch.nn.functional as F
import minigrid
import numpy as np
import matplotlib.pyplot as plt
import gym
from tqdm.notebook import tqdm
from minigrid.envs.doorkey import DoorKeyEnv
import pandas as pd
from gym.envs.registration import registry, register
import random
from tqdm import tqdm
from typing_extensions import Self
import matplotlib.pyplot as plt
from minigrid.wrappers import ObservationWrapper


# Function from https://github.com/ikostrikov/pytorch-a2c-ppo-acktr/blob/master/model.py
def init_params(m):
    """
    Initialize parameters of the network.
    m: torch.nn.Module
    """
    classname = m.__class__.__name__
    if classname.find("Linear") != -1:
        m.weight.data.normal_(0, 1)
        m.weight.data *= 1 / torch.sqrt(m.weight.data.pow(2).sum(1, keepdim=True))
        if m.bias is not None:
            m.bias.data.fill_(0)

class MyDoorKeyEnv(DoorKeyEnv):
    def __init__(self, size):
        self.render_mode = "rgb_array"
        super().__init__(size=size)

    def _reward(self):
        """
        Compute the reward to be given upon success
        """
        return 1

class ImgObsWrapper(ObservationWrapper):
    """
    Use the image as the only observation output, no language/mission.

    Parameters:
    - env (gym.Env): The environment to wrap.

    Methods:
    - observation(self, obs): Returns the image from the observation.
    - reset(self): Resets the environment and returns the initial observation.
    """

    def __init__(self, env):
        """
        Initializes the ImgObsWrapper with the given environment.

        Parameters:
        - env (gym.Env): The environment whose observations are to be wrapped.
        """
        super().__init__(env)
        self.observation_space = env.observation_space.spaces["image"]

    def observation(self, obs):
        """
        Extracts and returns the image data from the observation.

        Parameters:
        - obs (dict or tuple): The original observation from the environment, which could be either
        a dictionary or a tuple containing a dictionary.

        Returns:
        - np.ndarray: The image data extracted from the observation.
        """
        if type(obs) == tuple:
            return obs[0]["image"]
        return obs["image"]

    def reset(self):
        """
        Resets the environment and returns the initial observation image.

        Returns:
        - np.ndarray: The initial observation image of the reset environment.
        """
        obs = super().reset()
        return obs[0]
    
def get_door_key_env(size):
    """
    Returns a DoorKeyEnv environment with the given size.
    """
    env = MyDoorKeyEnv(size=size)
    env = ImgObsWrapper(env)

    env.reset()
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)

    # get an RGB image corresponding to the whole environment or the agent's point of view (https://github.com/Farama-Foundation/Minigrid/blob/master/minigrid/minigrid_env.py#L716)
    #            highlight (bool): If true, the agent's field of view or point of view is highlighted with a lighter gray color.
    #            tile_size (int): How many pixels will form a tile from the NxM grid.
    #            agent_pov (bool): If true, the rendered frame will only contain the point of view of the agent.
    frame = env.get_frame(highlight=env.highlight, tile_size=env.tile_size, agent_pov=env.agent_pov)
    # show an image to the notebook.
    plt.imshow(frame)

    return env


def make_env(size, seed):
    def thunk():
        env = get_door_key_env(size)
        env.action_space.seed(seed)

        return env

    return thunk

# %%
# TRY NOT TO MODIFY: start the game
obs, _ = envs.reset(seed=args.seed)
for global_step in range(args.total_timesteps):
    # ALGO LOGIC: put action logic here
    epsilon = linear_schedule(args.start_e, args.end_e, args.exploration_fraction * args.total_timesteps, global_step)
    if random.random() < epsilon:
        actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
    else:
        q_values = q_network(torch.Tensor(obs).to(device))
        actions = torch.argmax(q_values, dim=1).cpu().numpy()

    # TRY NOT TO MODIFY: execute the game and log data.
    next_obs, rewards, terminations, truncations, infos = envs.step(actions)

    # TRY NOT TO MODIFY: record rewards for plotting purposes
    if "final_info" in infos:
        for info in infos["final_info"]:
            if info and "episode" in info:
                print(f"global_step={global_step}, episodic_return={info['episode']['r']}")
                writer.add_scalar("charts/episodic_return", info["episode"]["r"], global_step)
                writer.add_scalar("charts/episodic_length", info["episode"]["l"], global_step)

    # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
    real_next_obs = next_obs.copy()
    for idx, trunc in enumerate(truncations):
        if trunc:
            real_next_obs[idx] = infos["final_observation"][idx]
    rb.add(obs, real_next_obs, actions, rewards, terminations, infos)

    # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
    obs = next_obs

    # ALGO LOGIC: training.
    if global_step > args.learning_starts:
        if global_step % args.train_frequency == 0:
            data = rb.sample(args.batch_size)
            with torch.no_grad():
                target_max, _ = target_network(data.next_observations).max(dim=1)
                td_target = data.rewards.flatten() + args.gamma * target_max * (1 - data.dones.flatten())
            old_val = q_network(data.observations).gather(1, data.actions).squeeze()
            loss = F.mse_loss(td_target, old_val)

            if global_step % 100 == 0:
                writer.add_scalar("losses/td_loss", loss, global_step)
                writer.add_scalar("losses/q_values", old_val.mean().item(), global_step)
                print("SPS:", int(global_step / (time.time() - start_time)))
                writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

            # optimize the model
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # update target network
        if global_step % args.target_network_frequency == 0:
            for target_network_param, q_network_param in zip(target_network.parameters(), q_network.parameters()):
                target_network_param.data.copy_(
                    args.tau * q_network_param.data + (1.0 - args.tau) * target_network_param.data
                )

if args.save_model:
    model_path = f"runs/{run_name}/{args.exp_name}.cleanrl_model"
    torch.save(q_network.state_dict(), model_path)
    print(f"model saved to {model_path}")
    from cleanrl_utils.evals.dqn_eval import evaluate

    episodic_returns = evaluate(
        model_path,
        make_env,
        args.env_id,
        eval_episodes=10,
        run_name=f"{run_name}-eval",
        Model=QNetwork,
        device=device,
        epsilon=0.05,
    )
    for idx, episodic_return in enumerate(episodic_returns):
        writer.add_scalar("eval/episodic_return", episodic_return, idx)

    if args.upload_model:
        from cleanrl_utils.huggingface import push_to_hub

        repo_name = f"{args.env_id}-{args.exp_name}-seed{args.seed}"
        repo_id = f"{args.hf_entity}/{repo_name}" if args.hf_entity else repo_name
        push_to_hub(args, episodic_returns, repo_id, "DQN", f"runs/{run_name}", f"videos/{run_name}-eval")

envs.close()
writer.close()
# Out:
# global_step=28, episodic_return=[29.]
# global_step=38, episodic_return=[10.]
# global_step=49, episodic_return=[11.]
# global_step=85, episodic_return=[36.]
# global_step=98, episodic_return=[13.]
# global_step=114, episodic_return=[16.]
# global_step=131, episodic_return=[17.]
# global_step=150, episodic_return=[19.]
# global_step=187, episodic_return=[37.]
# global_step=214, episodic_return=[27.]
# global_step=229, episodic_return=[15.]
# global_step=242, episodic_return=[13.]
# global_step=265, episodic_return=[23.]
# global_step=275, episodic_return=[10.]
# global_step=304, episodic_return=[29.]
# global_step=322, episodic_return=[18.]
# global_step=333, episodic_return=[11.]
# global_step=344, episodic_return=[11.]
# global_step=390, episodic_return=[46.]
# global_step=401, episodic_return=[11.]
# global_step=433, episodic_return=[32.]
# global_step=480, episodic_return=[47.]
# global_step=496, episodic_return=[16.]
# global_step=522, episodic_return=[26.]
# global_step=556, episodic_return=[34.]
# global_step=572, episodic_return=[16.]
# global_step=591, episodic_return=[19.]
# global_step=613, episodic_return=[22.]
# global_step=637, episodic_return=[24.]
# global_step=652, episodic_return=[15.]
# global_step=663, episodic_return=[11.]
# global_step=680, episodic_return=[17.]
# global_step=693, episodic_return=[13.]
# global_step=723, episodic_return=[30.]
# global_step=739, episodic_return=[16.]
# global_step=805, episodic_return=[66.]
# global_step=836, episodic_return=[31.]
# global_step=855, episodic_return=[19.]
# global_step=880, episodic_return=[25.]
# global_step=899, episodic_return=[19.]
# global_step=909, episodic_return=[10.]
# global_step=952, episodic_return=[43.]
# global_step=973, episodic_return=[21.]
# global_step=1005, episodic_return=[32.]
# global_step=1016, episodic_return=[11.]
# global_step=1064, episodic_return=[48.]
# global_step=1088, episodic_return=[24.]
# global_step=1100, episodic_return=[12.]
# global_step=1113, episodic_return=[13.]
# global_step=1125, episodic_return=[12.]
# global_step=1148, episodic_return=[23.]
# global_step=1166, episodic_return=[18.]
# global_step=1177, episodic_return=[11.]
# global_step=1189, episodic_return=[12.]
# global_step=1211, episodic_return=[22.]
# global_step=1222, episodic_return=[11.]
# global_step=1235, episodic_return=[13.]
# global_step=1253, episodic_return=[18.]
# global_step=1284, episodic_return=[31.]
# global_step=1310, episodic_return=[26.]
# global_step=1335, episodic_return=[25.]
# global_step=1354, episodic_return=[19.]
# global_step=1373, episodic_return=[19.]
# global_step=1391, episodic_return=[18.]
# global_step=1414, episodic_return=[23.]
# global_step=1442, episodic_return=[28.]
# global_step=1456, episodic_return=[14.]
# global_step=1498, episodic_return=[42.]
# global_step=1531, episodic_return=[33.]
# global_step=1550, episodic_return=[19.]
# global_step=1565, episodic_return=[15.]
# global_step=1577, episodic_return=[12.]
# global_step=1593, episodic_return=[16.]
# global_step=1615, episodic_return=[22.]
# global_step=1646, episodic_return=[31.]
# global_step=1668, episodic_return=[22.]
# global_step=1686, episodic_return=[18.]
# global_step=1698, episodic_return=[12.]
# global_step=1726, episodic_return=[28.]
# global_step=1738, episodic_return=[12.]
# global_step=1755, episodic_return=[17.]
# global_step=1773, episodic_return=[18.]
# global_step=1786, episodic_return=[13.]
# global_step=1797, episodic_return=[11.]
# global_step=1819, episodic_return=[22.]
# global_step=1828, episodic_return=[9.]
# global_step=1863, episodic_return=[35.]
# global_step=1873, episodic_return=[10.]
# global_step=1903, episodic_return=[30.]
# global_step=1913, episodic_return=[10.]
# global_step=1926, episodic_return=[13.]
# global_step=1946, episodic_return=[20.]
# global_step=1966, episodic_return=[20.]
# global_step=1978, episodic_return=[12.]
# global_step=2001, episodic_return=[23.]
# global_step=2020, episodic_return=[19.]
# global_step=2037, episodic_return=[17.]
# global_step=2051, episodic_return=[14.]
# global_step=2072, episodic_return=[21.]
# global_step=2091, episodic_return=[19.]
# global_step=2110, episodic_return=[19.]
# global_step=2135, episodic_return=[25.]
# global_step=2155, episodic_return=[20.]
# global_step=2189, episodic_return=[34.]
# global_step=2234, episodic_return=[45.]
# global_step=2273, episodic_return=[39.]
# global_step=2293, episodic_return=[20.]
# global_step=2310, episodic_return=[17.]
# global_step=2322, episodic_return=[12.]
# global_step=2335, episodic_return=[13.]
# global_step=2367, episodic_return=[32.]
# global_step=2401, episodic_return=[34.]
# global_step=2442, episodic_return=[41.]
# global_step=2453, episodic_return=[11.]
# global_step=2468, episodic_return=[15.]
# global_step=2479, episodic_return=[11.]
# global_step=2502, episodic_return=[23.]
# global_step=2519, episodic_return=[17.]
# global_step=2544, episodic_return=[25.]
# global_step=2559, episodic_return=[15.]
# global_step=2570, episodic_return=[11.]
# global_step=2645, episodic_return=[75.]
# global_step=2675, episodic_return=[30.]
# global_step=2687, episodic_return=[12.]
# global_step=2709, episodic_return=[22.]
# global_step=2720, episodic_return=[11.]
# global_step=2734, episodic_return=[14.]
# global_step=2754, episodic_return=[20.]
# global_step=2766, episodic_return=[12.]
# global_step=2794, episodic_return=[28.]
# global_step=2879, episodic_return=[85.]
# global_step=2900, episodic_return=[21.]
# global_step=2915, episodic_return=[15.]
# global_step=2939, episodic_return=[24.]
# global_step=2958, episodic_return=[19.]
# global_step=2978, episodic_return=[20.]
# global_step=2995, episodic_return=[17.]
# global_step=3016, episodic_return=[21.]
# global_step=3028, episodic_return=[12.]
# global_step=3041, episodic_return=[13.]
# global_step=3074, episodic_return=[33.]
# global_step=3118, episodic_return=[44.]
# global_step=3133, episodic_return=[15.]
# global_step=3149, episodic_return=[16.]
# global_step=3176, episodic_return=[27.]
# global_step=3189, episodic_return=[13.]
# global_step=3227, episodic_return=[38.]
# global_step=3263, episodic_return=[36.]
# global_step=3284, episodic_return=[21.]
# global_step=3298, episodic_return=[14.]
# global_step=3320, episodic_return=[22.]
# global_step=3341, episodic_return=[21.]
# global_step=3363, episodic_return=[22.]
# global_step=3381, episodic_return=[18.]
# global_step=3427, episodic_return=[46.]
# global_step=3475, episodic_return=[48.]
# global_step=3493, episodic_return=[18.]
# global_step=3511, episodic_return=[18.]
# global_step=3528, episodic_return=[17.]
# global_step=3540, episodic_return=[12.]
# global_step=3558, episodic_return=[18.]
# global_step=3571, episodic_return=[13.]
# global_step=3611, episodic_return=[40.]
# global_step=3653, episodic_return=[42.]
# global_step=3686, episodic_return=[33.]
# global_step=3696, episodic_return=[10.]
# global_step=3719, episodic_return=[23.]
# global_step=3728, episodic_return=[9.]
# global_step=3755, episodic_return=[27.]
# global_step=3769, episodic_return=[14.]
# global_step=3797, episodic_return=[28.]
# global_step=3839, episodic_return=[42.]
# global_step=3858, episodic_return=[19.]
# global_step=3869, episodic_return=[11.]
# global_step=3899, episodic_return=[30.]
# global_step=3921, episodic_return=[22.]
# global_step=3942, episodic_return=[21.]
# global_step=3960, episodic_return=[18.]
# global_step=4005, episodic_return=[45.]
# global_step=4020, episodic_return=[15.]
# global_step=4033, episodic_return=[13.]
# global_step=4044, episodic_return=[11.]
# global_step=4076, episodic_return=[32.]
# global_step=4089, episodic_return=[13.]
# global_step=4123, episodic_return=[34.]
# global_step=4139, episodic_return=[16.]
# global_step=4152, episodic_return=[13.]
# global_step=4173, episodic_return=[21.]
# global_step=4194, episodic_return=[21.]
# global_step=4210, episodic_return=[16.]
# global_step=4227, episodic_return=[17.]
# global_step=4264, episodic_return=[37.]
# global_step=4306, episodic_return=[42.]
# global_step=4322, episodic_return=[16.]
# global_step=4334, episodic_return=[12.]
# global_step=4344, episodic_return=[10.]
# global_step=4359, episodic_return=[15.]
# global_step=4378, episodic_return=[19.]
# global_step=4394, episodic_return=[16.]
# global_step=4450, episodic_return=[56.]
# global_step=4473, episodic_return=[23.]
# global_step=4491, episodic_return=[18.]
# global_step=4499, episodic_return=[8.]
# global_step=4515, episodic_return=[16.]
# global_step=4530, episodic_return=[15.]
# global_step=4540, episodic_return=[10.]
# global_step=4561, episodic_return=[21.]
# global_step=4574, episodic_return=[13.]
# global_step=4586, episodic_return=[12.]
# global_step=4624, episodic_return=[38.]
# global_step=4634, episodic_return=[10.]
# global_step=4645, episodic_return=[11.]
# global_step=4668, episodic_return=[23.]
# global_step=4679, episodic_return=[11.]
# global_step=4703, episodic_return=[24.]
# global_step=4726, episodic_return=[23.]
# global_step=4747, episodic_return=[21.]
# global_step=4765, episodic_return=[18.]
# global_step=4792, episodic_return=[27.]
# global_step=4818, episodic_return=[26.]
# global_step=4833, episodic_return=[15.]
# global_step=4869, episodic_return=[36.]
# global_step=4882, episodic_return=[13.]
# global_step=4915, episodic_return=[33.]
# global_step=4939, episodic_return=[24.]
# global_step=4955, episodic_return=[16.]
# global_step=4970, episodic_return=[15.]
# global_step=4990, episodic_return=[20.]
# global_step=5025, episodic_return=[35.]
# global_step=5054, episodic_return=[29.]
# global_step=5081, episodic_return=[27.]
# global_step=5094, episodic_return=[13.]
# global_step=5127, episodic_return=[33.]
# global_step=5140, episodic_return=[13.]
# global_step=5156, episodic_return=[16.]
# global_step=5185, episodic_return=[29.]
# global_step=5204, episodic_return=[19.]
# global_step=5227, episodic_return=[23.]
# global_step=5251, episodic_return=[24.]
# global_step=5265, episodic_return=[14.]
# global_step=5278, episodic_return=[13.]
# global_step=5288, episodic_return=[10.]
# global_step=5299, episodic_return=[11.]
# global_step=5311, episodic_return=[12.]
# global_step=5328, episodic_return=[17.]
# global_step=5343, episodic_return=[15.]
# global_step=5361, episodic_return=[18.]
# global_step=5375, episodic_return=[14.]
# global_step=5412, episodic_return=[37.]
# global_step=5432, episodic_return=[20.]
# global_step=5459, episodic_return=[27.]
# global_step=5487, episodic_return=[28.]
# global_step=5536, episodic_return=[49.]
# global_step=5546, episodic_return=[10.]
# global_step=5590, episodic_return=[44.]
# global_step=5605, episodic_return=[15.]
# global_step=5620, episodic_return=[15.]
# global_step=5631, episodic_return=[11.]
# global_step=5666, episodic_return=[35.]
# global_step=5686, episodic_return=[20.]
# global_step=5701, episodic_return=[15.]
# global_step=5722, episodic_return=[21.]
# global_step=5731, episodic_return=[9.]
# global_step=5740, episodic_return=[9.]
# global_step=5770, episodic_return=[30.]
# global_step=5843, episodic_return=[73.]
# global_step=5876, episodic_return=[33.]
# global_step=5901, episodic_return=[25.]
# global_step=5912, episodic_return=[11.]
# global_step=5926, episodic_return=[14.]
# global_step=5944, episodic_return=[18.]
# global_step=5961, episodic_return=[17.]
# global_step=5987, episodic_return=[26.]
# global_step=6000, episodic_return=[13.]
# global_step=6023, episodic_return=[23.]
# global_step=6046, episodic_return=[23.]
# global_step=6066, episodic_return=[20.]
# global_step=6093, episodic_return=[27.]
# global_step=6107, episodic_return=[14.]
# global_step=6123, episodic_return=[16.]
# global_step=6144, episodic_return=[21.]
# global_step=6166, episodic_return=[22.]
# global_step=6187, episodic_return=[21.]
# global_step=6198, episodic_return=[11.]
# global_step=6210, episodic_return=[12.]
# global_step=6260, episodic_return=[50.]
# global_step=6279, episodic_return=[19.]
# global_step=6296, episodic_return=[17.]
# global_step=6313, episodic_return=[17.]
# global_step=6326, episodic_return=[13.]
# global_step=6338, episodic_return=[12.]
# global_step=6395, episodic_return=[57.]
# global_step=6413, episodic_return=[18.]
# global_step=6481, episodic_return=[68.]
# global_step=6494, episodic_return=[13.]
# global_step=6506, episodic_return=[12.]
# global_step=6520, episodic_return=[14.]
# global_step=6566, episodic_return=[46.]
# global_step=6638, episodic_return=[72.]
# global_step=6648, episodic_return=[10.]
# global_step=6660, episodic_return=[12.]
# global_step=6676, episodic_return=[16.]
# global_step=6687, episodic_return=[11.]
# global_step=6712, episodic_return=[25.]
# global_step=6748, episodic_return=[36.]
# global_step=6780, episodic_return=[32.]
# global_step=6817, episodic_return=[37.]
# global_step=6841, episodic_return=[24.]
# global_step=6863, episodic_return=[22.]
# global_step=6874, episodic_return=[11.]
# global_step=6887, episodic_return=[13.]
# global_step=6907, episodic_return=[20.]
# global_step=6920, episodic_return=[13.]
# global_step=6956, episodic_return=[36.]
# global_step=6976, episodic_return=[20.]
# global_step=6989, episodic_return=[13.]
# global_step=7023, episodic_return=[34.]
# global_step=7044, episodic_return=[21.]
# global_step=7065, episodic_return=[21.]
# global_step=7078, episodic_return=[13.]
# global_step=7092, episodic_return=[14.]
# global_step=7107, episodic_return=[15.]
# global_step=7135, episodic_return=[28.]
# global_step=7165, episodic_return=[30.]
# global_step=7185, episodic_return=[20.]
# global_step=7204, episodic_return=[19.]
# global_step=7223, episodic_return=[19.]
# global_step=7243, episodic_return=[20.]
# global_step=7269, episodic_return=[26.]
# global_step=7290, episodic_return=[21.]
# global_step=7302, episodic_return=[12.]
# global_step=7340, episodic_return=[38.]
# global_step=7364, episodic_return=[24.]
# global_step=7406, episodic_return=[42.]
# global_step=7458, episodic_return=[52.]
# global_step=7474, episodic_return=[16.]
# global_step=7495, episodic_return=[21.]
# global_step=7548, episodic_return=[53.]
# global_step=7572, episodic_return=[24.]
# global_step=7592, episodic_return=[20.]
# global_step=7615, episodic_return=[23.]
# global_step=7643, episodic_return=[28.]
# global_step=7670, episodic_return=[27.]
# global_step=7698, episodic_return=[28.]
# global_step=7709, episodic_return=[11.]
# global_step=7723, episodic_return=[14.]
# global_step=7742, episodic_return=[19.]
# global_step=7756, episodic_return=[14.]
# global_step=7798, episodic_return=[42.]
# global_step=7817, episodic_return=[19.]
# global_step=7835, episodic_return=[18.]
# global_step=7860, episodic_return=[25.]
# global_step=7879, episodic_return=[19.]
# global_step=7918, episodic_return=[39.]
# global_step=7933, episodic_return=[15.]
# global_step=7967, episodic_return=[34.]
# global_step=8023, episodic_return=[56.]
# global_step=8051, episodic_return=[28.]
# global_step=8064, episodic_return=[13.]
# global_step=8107, episodic_return=[43.]
# global_step=8144, episodic_return=[37.]
# global_step=8179, episodic_return=[35.]
# global_step=8189, episodic_return=[10.]
# global_step=8208, episodic_return=[19.]
# global_step=8243, episodic_return=[35.]
# global_step=8257, episodic_return=[14.]
# global_step=8323, episodic_return=[66.]
# global_step=8334, episodic_return=[11.]
# global_step=8343, episodic_return=[9.]
# global_step=8355, episodic_return=[12.]
# global_step=8375, episodic_return=[20.]
# global_step=8390, episodic_return=[15.]
# global_step=8416, episodic_return=[26.]
# global_step=8439, episodic_return=[23.]
# global_step=8460, episodic_return=[21.]
# global_step=8473, episodic_return=[13.]
# global_step=8488, episodic_return=[15.]
# global_step=8525, episodic_return=[37.]
# global_step=8559, episodic_return=[34.]
# global_step=8572, episodic_return=[13.]
# global_step=8601, episodic_return=[29.]
# global_step=8630, episodic_return=[29.]
# global_step=8673, episodic_return=[43.]
# global_step=8693, episodic_return=[20.]
# global_step=8704, episodic_return=[11.]
# global_step=8720, episodic_return=[16.]
# global_step=8746, episodic_return=[26.]
# global_step=8762, episodic_return=[16.]
# global_step=8782, episodic_return=[20.]
# global_step=8809, episodic_return=[27.]
# global_step=8861, episodic_return=[52.]
# global_step=8876, episodic_return=[15.]
# global_step=8893, episodic_return=[17.]
# global_step=8936, episodic_return=[43.]
# global_step=8955, episodic_return=[19.]
# global_step=8986, episodic_return=[31.]
# global_step=9004, episodic_return=[18.]
# global_step=9033, episodic_return=[29.]
# global_step=9051, episodic_return=[18.]
# global_step=9066, episodic_return=[15.]
# global_step=9079, episodic_return=[13.]
# global_step=9093, episodic_return=[14.]
# global_step=9111, episodic_return=[18.]
# global_step=9133, episodic_return=[22.]
# global_step=9151, episodic_return=[18.]
# global_step=9161, episodic_return=[10.]
# global_step=9183, episodic_return=[22.]
# global_step=9199, episodic_return=[16.]
# global_step=9211, episodic_return=[12.]
# global_step=9237, episodic_return=[26.]
# global_step=9261, episodic_return=[24.]
# global_step=9285, episodic_return=[24.]
# global_step=9315, episodic_return=[30.]
# global_step=9326, episodic_return=[11.]
# global_step=9381, episodic_return=[55.]
# global_step=9400, episodic_return=[19.]
# global_step=9423, episodic_return=[23.]
# global_step=9437, episodic_return=[14.]
# global_step=9467, episodic_return=[30.]
# global_step=9476, episodic_return=[9.]
# global_step=9499, episodic_return=[23.]
# global_step=9513, episodic_return=[14.]
# global_step=9537, episodic_return=[24.]
# global_step=9588, episodic_return=[51.]
# global_step=9601, episodic_return=[13.]
# global_step=9617, episodic_return=[16.]
# global_step=9630, episodic_return=[13.]
# global_step=9642, episodic_return=[12.]
# global_step=9678, episodic_return=[36.]
# global_step=9690, episodic_return=[12.]
# global_step=9711, episodic_return=[21.]
# global_step=9742, episodic_return=[31.]
# global_step=9757, episodic_return=[15.]
# global_step=9782, episodic_return=[25.]
# global_step=9796, episodic_return=[14.]
# global_step=9874, episodic_return=[78.]
# global_step=9903, episodic_return=[29.]
# global_step=9917, episodic_return=[14.]
# global_step=9933, episodic_return=[16.]
# global_step=9952, episodic_return=[19.]
# global_step=9966, episodic_return=[14.]
# global_step=9994, episodic_return=[28.]
# global_step=10009, episodic_return=[15.]
# global_step=10045, episodic_return=[36.]
# global_step=10057, episodic_return=[12.]
# global_step=10079, episodic_return=[22.]
# global_step=10092, episodic_return=[13.]
# SPS: 2213
# global_step=10113, episodic_return=[21.]
# global_step=10143, episodic_return=[30.]
# global_step=10155, episodic_return=[12.]
# SPS: 2217
# global_step=10201, episodic_return=[46.]
# global_step=10227, episodic_return=[26.]
# global_step=10257, episodic_return=[30.]
# SPS: 2221
# global_step=10312, episodic_return=[55.]
# global_step=10324, episodic_return=[12.]
# global_step=10339, episodic_return=[15.]
# global_step=10352, episodic_return=[13.]
# global_step=10386, episodic_return=[34.]
# global_step=10399, episodic_return=[13.]
# SPS: 2225
# global_step=10417, episodic_return=[18.]
# global_step=10437, episodic_return=[20.]
# global_step=10454, episodic_return=[17.]
# global_step=10463, episodic_return=[9.]
# global_step=10492, episodic_return=[29.]
# SPS: 2228
# global_step=10505, episodic_return=[13.]
# global_step=10540, episodic_return=[35.]
# global_step=10556, episodic_return=[16.]
# global_step=10593, episodic_return=[37.]
# SPS: 2233
# global_step=10651, episodic_return=[58.]
# global_step=10676, episodic_return=[25.]
# global_step=10688, episodic_return=[12.]
# SPS: 2237
# global_step=10709, episodic_return=[21.]
# global_step=10734, episodic_return=[25.]
# global_step=10746, episodic_return=[12.]
# global_step=10761, episodic_return=[15.]
# global_step=10774, episodic_return=[13.]
# SPS: 2242
# global_step=10804, episodic_return=[30.]
# global_step=10830, episodic_return=[26.]
# global_step=10846, episodic_return=[16.]
# global_step=10863, episodic_return=[17.]
# global_step=10875, episodic_return=[12.]
# global_step=10889, episodic_return=[14.]
# SPS: 2248
# global_step=10903, episodic_return=[14.]
# global_step=10920, episodic_return=[17.]
# global_step=10937, episodic_return=[17.]
# global_step=10969, episodic_return=[32.]
# global_step=10989, episodic_return=[20.]
# SPS: 2252
# global_step=11014, episodic_return=[25.]
# global_step=11028, episodic_return=[14.]
# global_step=11057, episodic_return=[29.]
# global_step=11090, episodic_return=[33.]
# SPS: 2258
# global_step=11104, episodic_return=[14.]
# global_step=11141, episodic_return=[37.]
# global_step=11171, episodic_return=[30.]
# global_step=11185, episodic_return=[14.]
# SPS: 2261
# global_step=11222, episodic_return=[37.]
# global_step=11248, episodic_return=[26.]
# global_step=11265, episodic_return=[17.]
# global_step=11297, episodic_return=[32.]
# SPS: 2266
# global_step=11313, episodic_return=[16.]
# global_step=11333, episodic_return=[20.]
# global_step=11353, episodic_return=[20.]
# global_step=11368, episodic_return=[15.]
# global_step=11386, episodic_return=[18.]
# global_step=11399, episodic_return=[13.]
# SPS: 2270
# global_step=11422, episodic_return=[23.]
# global_step=11439, episodic_return=[17.]
# global_step=11479, episodic_return=[40.]
# SPS: 2275
# global_step=11503, episodic_return=[24.]
# global_step=11519, episodic_return=[16.]
# global_step=11534, episodic_return=[15.]
# global_step=11550, episodic_return=[16.]
# global_step=11569, episodic_return=[19.]
# global_step=11592, episodic_return=[23.]
# SPS: 2278
# global_step=11609, episodic_return=[17.]
# global_step=11627, episodic_return=[18.]
# global_step=11639, episodic_return=[12.]
# global_step=11657, episodic_return=[18.]
# global_step=11669, episodic_return=[12.]
# global_step=11681, episodic_return=[12.]
# SPS: 2281
# global_step=11701, episodic_return=[20.]
# global_step=11716, episodic_return=[15.]
# global_step=11744, episodic_return=[28.]
# global_step=11775, episodic_return=[31.]
# global_step=11793, episodic_return=[18.]
# SPS: 2284
# global_step=11819, episodic_return=[26.]
# global_step=11846, episodic_return=[27.]
# global_step=11866, episodic_return=[20.]
# global_step=11886, episodic_return=[20.]
# global_step=11898, episodic_return=[12.]
# SPS: 2289
# global_step=11908, episodic_return=[10.]
# global_step=11916, episodic_return=[8.]
# global_step=11956, episodic_return=[40.]
# global_step=11970, episodic_return=[14.]
# global_step=11987, episodic_return=[17.]
# SPS: 2294
# global_step=12010, episodic_return=[23.]
# global_step=12032, episodic_return=[22.]
# global_step=12055, episodic_return=[23.]
# global_step=12070, episodic_return=[15.]
# global_step=12080, episodic_return=[10.]
# SPS: 2296
# global_step=12115, episodic_return=[35.]
# global_step=12131, episodic_return=[16.]
# global_step=12179, episodic_return=[48.]
# global_step=12191, episodic_return=[12.]
# SPS: 2301
# global_step=12215, episodic_return=[24.]
# global_step=12254, episodic_return=[39.]
# global_step=12271, episodic_return=[17.]
# global_step=12294, episodic_return=[23.]
# SPS: 2305
# global_step=12324, episodic_return=[30.]
# global_step=12353, episodic_return=[29.]
# global_step=12366, episodic_return=[13.]
# global_step=12396, episodic_return=[30.]
# SPS: 2309
# global_step=12425, episodic_return=[29.]
# global_step=12440, episodic_return=[15.]
# global_step=12452, episodic_return=[12.]
# global_step=12481, episodic_return=[29.]
# global_step=12494, episodic_return=[13.]
# SPS: 2313
# global_step=12504, episodic_return=[10.]
# global_step=12524, episodic_return=[20.]
# global_step=12534, episodic_return=[10.]
# global_step=12549, episodic_return=[15.]
# global_step=12576, episodic_return=[27.]
# global_step=12592, episodic_return=[16.]
# SPS: 2315
# global_step=12609, episodic_return=[17.]
# global_step=12634, episodic_return=[25.]
# global_step=12647, episodic_return=[13.]
# global_step=12661, episodic_return=[14.]
# global_step=12682, episodic_return=[21.]
# global_step=12694, episodic_return=[12.]
# SPS: 2317
# global_step=12713, episodic_return=[19.]
# global_step=12748, episodic_return=[35.]
# global_step=12760, episodic_return=[12.]
# global_step=12777, episodic_return=[17.]
# SPS: 2321
# global_step=12801, episodic_return=[24.]
# global_step=12834, episodic_return=[33.]
# global_step=12851, episodic_return=[17.]
# global_step=12873, episodic_return=[22.]
# global_step=12887, episodic_return=[14.]
# SPS: 2324
# global_step=12902, episodic_return=[15.]
# global_step=12913, episodic_return=[11.]
# global_step=12922, episodic_return=[9.]
# global_step=12953, episodic_return=[31.]
# global_step=12996, episodic_return=[43.]
# SPS: 2327
# global_step=13034, episodic_return=[38.]
# global_step=13055, episodic_return=[21.]
# global_step=13070, episodic_return=[15.]
# global_step=13081, episodic_return=[11.]
# global_step=13097, episodic_return=[16.]
# SPS: 2330
# global_step=13112, episodic_return=[15.]
# global_step=13151, episodic_return=[39.]
# global_step=13163, episodic_return=[12.]
# global_step=13185, episodic_return=[22.]
# SPS: 2333
# global_step=13206, episodic_return=[21.]
# global_step=13230, episodic_return=[24.]
# global_step=13248, episodic_return=[18.]
# global_step=13276, episodic_return=[28.]
# global_step=13287, episodic_return=[11.]
# SPS: 2337
# global_step=13305, episodic_return=[18.]
# global_step=13321, episodic_return=[16.]
# global_step=13341, episodic_return=[20.]
# global_step=13356, episodic_return=[15.]
# global_step=13369, episodic_return=[13.]
# global_step=13381, episodic_return=[12.]
# global_step=13394, episodic_return=[13.]
# SPS: 2340
# global_step=13465, episodic_return=[71.]
# global_step=13486, episodic_return=[21.]
# global_step=13496, episodic_return=[10.]
# SPS: 2343
# global_step=13531, episodic_return=[35.]
# global_step=13553, episodic_return=[22.]
# global_step=13575, episodic_return=[22.]
# global_step=13592, episodic_return=[17.]
# SPS: 2346
# global_step=13614, episodic_return=[22.]
# global_step=13628, episodic_return=[14.]
# global_step=13642, episodic_return=[14.]
# global_step=13653, episodic_return=[11.]
# global_step=13671, episodic_return=[18.]
# global_step=13693, episodic_return=[22.]
# SPS: 2348
# global_step=13783, episodic_return=[90.]
# SPS: 2353
# global_step=13815, episodic_return=[32.]
# global_step=13838, episodic_return=[23.]
# global_step=13873, episodic_return=[35.]
# global_step=13892, episodic_return=[19.]
# SPS: 2356
# global_step=13917, episodic_return=[25.]
# global_step=13951, episodic_return=[34.]
# global_step=13973, episodic_return=[22.]
# global_step=13984, episodic_return=[11.]
# global_step=13995, episodic_return=[11.]
# SPS: 2359
# global_step=14023, episodic_return=[28.]
# global_step=14042, episodic_return=[19.]
# global_step=14077, episodic_return=[35.]
# global_step=14100, episodic_return=[23.]
# SPS: 2361
# global_step=14128, episodic_return=[28.]
# global_step=14143, episodic_return=[15.]
# global_step=14165, episodic_return=[22.]
# SPS: 2363
# global_step=14203, episodic_return=[38.]
# global_step=14231, episodic_return=[28.]
# global_step=14245, episodic_return=[14.]
# global_step=14260, episodic_return=[15.]
# global_step=14285, episodic_return=[25.]
# SPS: 2366
# global_step=14307, episodic_return=[22.]
# global_step=14321, episodic_return=[14.]
# global_step=14337, episodic_return=[16.]
# global_step=14353, episodic_return=[16.]
# global_step=14400, episodic_return=[47.]
# SPS: 2369
# global_step=14412, episodic_return=[12.]
# global_step=14422, episodic_return=[10.]
# global_step=14436, episodic_return=[14.]
# global_step=14451, episodic_return=[15.]
# global_step=14466, episodic_return=[15.]
# global_step=14478, episodic_return=[12.]
# SPS: 2372
# global_step=14527, episodic_return=[49.]
# global_step=14537, episodic_return=[10.]
# global_step=14550, episodic_return=[13.]
# global_step=14567, episodic_return=[17.]
# global_step=14578, episodic_return=[11.]
# global_step=14589, episodic_return=[11.]
# SPS: 2375
# global_step=14604, episodic_return=[15.]
# global_step=14628, episodic_return=[24.]
# global_step=14650, episodic_return=[22.]
# global_step=14663, episodic_return=[13.]
# global_step=14672, episodic_return=[9.]
# global_step=14683, episodic_return=[11.]
# global_step=14699, episodic_return=[16.]
# SPS: 2377
# global_step=14733, episodic_return=[34.]
# global_step=14745, episodic_return=[12.]
# global_step=14759, episodic_return=[14.]
# global_step=14773, episodic_return=[14.]
# global_step=14787, episodic_return=[14.]
# SPS: 2378
# global_step=14804, episodic_return=[17.]
# global_step=14817, episodic_return=[13.]
# global_step=14827, episodic_return=[10.]
# global_step=14846, episodic_return=[19.]
# global_step=14863, episodic_return=[17.]
# global_step=14872, episodic_return=[9.]
# global_step=14885, episodic_return=[13.]
# SPS: 2380
# global_step=14928, episodic_return=[43.]
# global_step=14949, episodic_return=[21.]
# global_step=14965, episodic_return=[16.]
# global_step=14979, episodic_return=[14.]
# global_step=14992, episodic_return=[13.]
# SPS: 2382
# global_step=15019, episodic_return=[27.]
# global_step=15036, episodic_return=[17.]
# global_step=15057, episodic_return=[21.]
# global_step=15072, episodic_return=[15.]
# global_step=15086, episodic_return=[14.]
# SPS: 2384
# global_step=15103, episodic_return=[17.]
# global_step=15118, episodic_return=[15.]
# global_step=15137, episodic_return=[19.]
# global_step=15162, episodic_return=[25.]
# global_step=15180, episodic_return=[18.]
# global_step=15200, episodic_return=[20.]
# SPS: 2388
# global_step=15240, episodic_return=[40.]
# global_step=15251, episodic_return=[11.]
# global_step=15269, episodic_return=[18.]
# global_step=15287, episodic_return=[18.]
# SPS: 2391
# global_step=15306, episodic_return=[19.]
# global_step=15360, episodic_return=[54.]
# global_step=15382, episodic_return=[22.]
# SPS: 2393
# global_step=15404, episodic_return=[22.]
# global_step=15443, episodic_return=[39.]
# global_step=15457, episodic_return=[14.]
# global_step=15472, episodic_return=[15.]
# global_step=15496, episodic_return=[24.]
# SPS: 2395
# global_step=15511, episodic_return=[15.]
# global_step=15532, episodic_return=[21.]
# global_step=15558, episodic_return=[26.]
# global_step=15579, episodic_return=[21.]
# global_step=15593, episodic_return=[14.]
# SPS: 2398
# global_step=15615, episodic_return=[22.]
# global_step=15637, episodic_return=[22.]
# global_step=15648, episodic_return=[11.]
# global_step=15675, episodic_return=[27.]
# global_step=15690, episodic_return=[15.]
# SPS: 2401
# global_step=15709, episodic_return=[19.]
# global_step=15722, episodic_return=[13.]
# global_step=15743, episodic_return=[21.]
# global_step=15753, episodic_return=[10.]
# global_step=15772, episodic_return=[19.]
# global_step=15792, episodic_return=[20.]
# SPS: 2397
# global_step=15805, episodic_return=[13.]
# global_step=15819, episodic_return=[14.]
# global_step=15830, episodic_return=[11.]
# global_step=15860, episodic_return=[30.]
# global_step=15872, episodic_return=[12.]
# SPS: 2394
# global_step=15906, episodic_return=[34.]
# global_step=15925, episodic_return=[19.]
# global_step=15948, episodic_return=[23.]
# global_step=15981, episodic_return=[33.]
# SPS: 2396
# global_step=16004, episodic_return=[23.]
# global_step=16021, episodic_return=[17.]
# global_step=16035, episodic_return=[14.]
# global_step=16091, episodic_return=[56.]
# SPS: 2400
# global_step=16101, episodic_return=[10.]
# global_step=16111, episodic_return=[10.]
# global_step=16133, episodic_return=[22.]
# global_step=16149, episodic_return=[16.]
# global_step=16195, episodic_return=[46.]
# SPS: 2402
# global_step=16250, episodic_return=[55.]
# global_step=16265, episodic_return=[15.]
# global_step=16273, episodic_return=[8.]
# SPS: 2405
# global_step=16306, episodic_return=[33.]
# global_step=16319, episodic_return=[13.]
# global_step=16333, episodic_return=[14.]
# global_step=16368, episodic_return=[35.]
# global_step=16378, episodic_return=[10.]
# global_step=16391, episodic_return=[13.]
# SPS: 2408
# global_step=16403, episodic_return=[12.]
# global_step=16415, episodic_return=[12.]
# global_step=16431, episodic_return=[16.]
# global_step=16475, episodic_return=[44.]
# SPS: 2410
# global_step=16535, episodic_return=[60.]
# global_step=16564, episodic_return=[29.]
# global_step=16574, episodic_return=[10.]
# global_step=16595, episodic_return=[21.]
# SPS: 2412
# global_step=16614, episodic_return=[19.]
# global_step=16649, episodic_return=[35.]
# global_step=16664, episodic_return=[15.]
# global_step=16677, episodic_return=[13.]
# global_step=16692, episodic_return=[15.]
# SPS: 2415
# global_step=16709, episodic_return=[17.]
# global_step=16737, episodic_return=[28.]
# global_step=16761, episodic_return=[24.]
# global_step=16785, episodic_return=[24.]
# global_step=16796, episodic_return=[11.]
# SPS: 2417
# global_step=16829, episodic_return=[33.]
# global_step=16858, episodic_return=[29.]
# global_step=16893, episodic_return=[35.]
# SPS: 2420
# global_step=16911, episodic_return=[18.]
# global_step=16927, episodic_return=[16.]
# global_step=16952, episodic_return=[25.]
# global_step=16993, episodic_return=[41.]
# SPS: 2423
# global_step=17013, episodic_return=[20.]
# global_step=17038, episodic_return=[25.]
# global_step=17055, episodic_return=[17.]
# global_step=17067, episodic_return=[12.]
# global_step=17080, episodic_return=[13.]
# SPS: 2426
# global_step=17129, episodic_return=[49.]
# global_step=17140, episodic_return=[11.]
# global_step=17153, episodic_return=[13.]
# global_step=17175, episodic_return=[22.]
# global_step=17194, episodic_return=[19.]
# SPS: 2427
# global_step=17210, episodic_return=[16.]
# global_step=17227, episodic_return=[17.]
# global_step=17239, episodic_return=[12.]
# global_step=17256, episodic_return=[17.]
# global_step=17298, episodic_return=[42.]
# SPS: 2428
# global_step=17319, episodic_return=[21.]
# global_step=17332, episodic_return=[13.]
# global_step=17343, episodic_return=[11.]
# global_step=17373, episodic_return=[30.]
# global_step=17400, episodic_return=[27.]
# SPS: 2429
# global_step=17423, episodic_return=[23.]
# global_step=17451, episodic_return=[28.]
# global_step=17465, episodic_return=[14.]
# global_step=17493, episodic_return=[28.]
# SPS: 2431
# global_step=17517, episodic_return=[24.]
# global_step=17542, episodic_return=[25.]
# global_step=17576, episodic_return=[34.]
# global_step=17594, episodic_return=[18.]
# SPS: 2434
# global_step=17629, episodic_return=[35.]
# global_step=17641, episodic_return=[12.]
# global_step=17678, episodic_return=[37.]
# SPS: 2434
# global_step=17747, episodic_return=[69.]
# global_step=17779, episodic_return=[32.]
# SPS: 2437
# global_step=17803, episodic_return=[24.]
# global_step=17818, episodic_return=[15.]
# global_step=17828, episodic_return=[10.]
# global_step=17889, episodic_return=[61.]
# SPS: 2440
# global_step=17905, episodic_return=[16.]
# global_step=17916, episodic_return=[11.]
# global_step=17928, episodic_return=[12.]
# global_step=17947, episodic_return=[19.]
# global_step=17969, episodic_return=[22.]
# global_step=17996, episodic_return=[27.]
# SPS: 2442
# global_step=18012, episodic_return=[16.]
# global_step=18040, episodic_return=[28.]
# global_step=18054, episodic_return=[14.]
# global_step=18074, episodic_return=[20.]
# SPS: 2443
# global_step=18101, episodic_return=[27.]
# global_step=18123, episodic_return=[22.]
# global_step=18143, episodic_return=[20.]
# global_step=18169, episodic_return=[26.]
# SPS: 2446
# global_step=18222, episodic_return=[53.]
# global_step=18242, episodic_return=[20.]
# global_step=18255, episodic_return=[13.]
# global_step=18265, episodic_return=[10.]
# global_step=18291, episodic_return=[26.]
# SPS: 2446
# global_step=18305, episodic_return=[14.]
# global_step=18337, episodic_return=[32.]
# global_step=18352, episodic_return=[15.]
# global_step=18367, episodic_return=[15.]
# SPS: 2448
# global_step=18417, episodic_return=[50.]
# global_step=18430, episodic_return=[13.]
# global_step=18472, episodic_return=[42.]
# global_step=18485, episodic_return=[13.]
# SPS: 2451
# global_step=18504, episodic_return=[19.]
# global_step=18530, episodic_return=[26.]
# global_step=18563, episodic_return=[33.]
# global_step=18582, episodic_return=[19.]
# SPS: 2453
# global_step=18606, episodic_return=[24.]
# global_step=18623, episodic_return=[17.]
# global_step=18635, episodic_return=[12.]
# global_step=18653, episodic_return=[18.]
# global_step=18700, episodic_return=[47.]
# SPS: 2455
# global_step=18729, episodic_return=[29.]
# global_step=18742, episodic_return=[13.]
# global_step=18764, episodic_return=[22.]
# global_step=18779, episodic_return=[15.]
# global_step=18799, episodic_return=[20.]
# SPS: 2456
# global_step=18839, episodic_return=[40.]
# global_step=18855, episodic_return=[16.]
# global_step=18867, episodic_return=[12.]
# global_step=18880, episodic_return=[13.]
# global_step=18893, episodic_return=[13.]
# SPS: 2457
# global_step=18907, episodic_return=[14.]
# global_step=18919, episodic_return=[12.]
# global_step=18930, episodic_return=[11.]
# global_step=18964, episodic_return=[34.]
# global_step=18984, episodic_return=[20.]
# SPS: 2459
# global_step=19016, episodic_return=[32.]
# global_step=19040, episodic_return=[24.]
# global_step=19061, episodic_return=[21.]
# global_step=19073, episodic_return=[12.]
# global_step=19085, episodic_return=[12.]
# SPS: 2461
# global_step=19106, episodic_return=[21.]
# global_step=19151, episodic_return=[45.]
# SPS: 2464
# global_step=19230, episodic_return=[79.]
# global_step=19297, episodic_return=[67.]
# SPS: 2466
# global_step=19318, episodic_return=[21.]
# global_step=19335, episodic_return=[17.]
# global_step=19354, episodic_return=[19.]
# global_step=19377, episodic_return=[23.]
# SPS: 2468
# global_step=19402, episodic_return=[25.]
# global_step=19429, episodic_return=[27.]
# global_step=19447, episodic_return=[18.]
# SPS: 2470
# global_step=19511, episodic_return=[64.]
# global_step=19541, episodic_return=[30.]
# global_step=19555, episodic_return=[14.]
# global_step=19572, episodic_return=[17.]
# SPS: 2472
# global_step=19606, episodic_return=[34.]
# global_step=19616, episodic_return=[10.]
# global_step=19642, episodic_return=[26.]
# global_step=19700, episodic_return=[58.]
# SPS: 2474
# global_step=19717, episodic_return=[17.]
# global_step=19746, episodic_return=[29.]
# global_step=19764, episodic_return=[18.]
# global_step=19797, episodic_return=[33.]
# SPS: 2476
# global_step=19843, episodic_return=[46.]
# global_step=19856, episodic_return=[13.]
# global_step=19870, episodic_return=[14.]
# global_step=19894, episodic_return=[24.]
# SPS: 2477
# global_step=19908, episodic_return=[14.]
# global_step=19940, episodic_return=[32.]
# global_step=19991, episodic_return=[51.]
# SPS: 2480
# global_step=20007, episodic_return=[16.]
# global_step=20019, episodic_return=[12.]
# global_step=20030, episodic_return=[11.]
# global_step=20052, episodic_return=[22.]
# SPS: 2480
# global_step=20115, episodic_return=[63.]
# global_step=20140, episodic_return=[25.]
# global_step=20161, episodic_return=[21.]
# global_step=20190, episodic_return=[29.]
# SPS: 2482
# global_step=20221, episodic_return=[31.]
# global_step=20250, episodic_return=[29.]
# global_step=20270, episodic_return=[20.]
# SPS: 2483
# global_step=20329, episodic_return=[59.]
# global_step=20357, episodic_return=[28.]
# global_step=20374, episodic_return=[17.]
# SPS: 2486
# global_step=20409, episodic_return=[35.]
# global_step=20430, episodic_return=[21.]
# global_step=20455, episodic_return=[25.]
# global_step=20477, episodic_return=[22.]
# global_step=20490, episodic_return=[13.]
# SPS: 2488
# global_step=20508, episodic_return=[18.]
# global_step=20522, episodic_return=[14.]
# global_step=20542, episodic_return=[20.]
# global_step=20563, episodic_return=[21.]
# global_step=20578, episodic_return=[15.]
# global_step=20598, episodic_return=[20.]
# SPS: 2490
# global_step=20622, episodic_return=[24.]
# global_step=20637, episodic_return=[15.]
# global_step=20663, episodic_return=[26.]
# global_step=20681, episodic_return=[18.]
# SPS: 2491
# global_step=20713, episodic_return=[32.]
# global_step=20756, episodic_return=[43.]
# global_step=20774, episodic_return=[18.]
# SPS: 2492
# global_step=20809, episodic_return=[35.]
# global_step=20836, episodic_return=[27.]
# global_step=20857, episodic_return=[21.]
# global_step=20869, episodic_return=[12.]
# global_step=20896, episodic_return=[27.]
# SPS: 2493
# global_step=20938, episodic_return=[42.]
# global_step=20970, episodic_return=[32.]
# global_step=20992, episodic_return=[22.]
# SPS: 2495
# global_step=21020, episodic_return=[28.]
# global_step=21031, episodic_return=[11.]
# global_step=21060, episodic_return=[29.]
# global_step=21081, episodic_return=[21.]
# global_step=21097, episodic_return=[16.]
# SPS: 2497
# global_step=21116, episodic_return=[19.]
# global_step=21134, episodic_return=[18.]
# global_step=21156, episodic_return=[22.]
# global_step=21168, episodic_return=[12.]
# global_step=21195, episodic_return=[27.]
# SPS: 2499
# global_step=21203, episodic_return=[8.]
# global_step=21240, episodic_return=[37.]
# global_step=21254, episodic_return=[14.]
# global_step=21295, episodic_return=[41.]
# SPS: 2500
# global_step=21314, episodic_return=[19.]
# global_step=21353, episodic_return=[39.]
# global_step=21369, episodic_return=[16.]
# global_step=21396, episodic_return=[27.]
# SPS: 2502
# global_step=21417, episodic_return=[21.]
# global_step=21475, episodic_return=[58.]
# SPS: 2503
# global_step=21514, episodic_return=[39.]
# global_step=21531, episodic_return=[17.]
# global_step=21544, episodic_return=[13.]
# global_step=21596, episodic_return=[52.]
# SPS: 2503
# global_step=21622, episodic_return=[26.]
# global_step=21641, episodic_return=[19.]
# global_step=21656, episodic_return=[15.]
# global_step=21680, episodic_return=[24.]
# SPS: 2502
# global_step=21711, episodic_return=[31.]
# global_step=21725, episodic_return=[14.]
# global_step=21739, episodic_return=[14.]
# SPS: 2499
# global_step=21818, episodic_return=[79.]
# global_step=21833, episodic_return=[15.]
# global_step=21897, episodic_return=[64.]
# SPS: 2498
# global_step=21930, episodic_return=[33.]
# global_step=21959, episodic_return=[29.]
# SPS: 2499
# global_step=22023, episodic_return=[64.]
# global_step=22033, episodic_return=[10.]
# global_step=22047, episodic_return=[14.]
# global_step=22058, episodic_return=[11.]
# SPS: 2500
# global_step=22126, episodic_return=[68.]
# global_step=22145, episodic_return=[19.]
# global_step=22156, episodic_return=[11.]
# global_step=22173, episodic_return=[17.]
# SPS: 2501
# global_step=22207, episodic_return=[34.]
# global_step=22251, episodic_return=[44.]
# global_step=22273, episodic_return=[22.]
# global_step=22292, episodic_return=[19.]
# SPS: 2501
# global_step=22324, episodic_return=[32.]
# global_step=22338, episodic_return=[14.]
# global_step=22377, episodic_return=[39.]
# SPS: 2501
# global_step=22405, episodic_return=[28.]
# global_step=22427, episodic_return=[22.]
# global_step=22440, episodic_return=[13.]
# global_step=22457, episodic_return=[17.]
# SPS: 2502
# global_step=22512, episodic_return=[55.]
# global_step=22536, episodic_return=[24.]
# global_step=22563, episodic_return=[27.]
# SPS: 2504
# global_step=22623, episodic_return=[60.]
# global_step=22632, episodic_return=[9.]
# global_step=22661, episodic_return=[29.]
# global_step=22685, episodic_return=[24.]
# global_step=22699, episodic_return=[14.]
# SPS: 2506
# global_step=22715, episodic_return=[16.]
# global_step=22749, episodic_return=[34.]
# global_step=22773, episodic_return=[24.]
# global_step=22787, episodic_return=[14.]
# SPS: 2506
# global_step=22847, episodic_return=[60.]
# SPS: 2506
# global_step=22907, episodic_return=[60.]
# global_step=22932, episodic_return=[25.]
# global_step=22964, episodic_return=[32.]
# global_step=22992, episodic_return=[28.]
# SPS: 2506
# global_step=23005, episodic_return=[13.]
# global_step=23032, episodic_return=[27.]
# global_step=23052, episodic_return=[20.]
# global_step=23068, episodic_return=[16.]
# SPS: 2506
# global_step=23111, episodic_return=[43.]
# global_step=23121, episodic_return=[10.]
# global_step=23148, episodic_return=[27.]
# global_step=23170, episodic_return=[22.]
# global_step=23181, episodic_return=[11.]
# SPS: 2506
# global_step=23208, episodic_return=[27.]
# global_step=23233, episodic_return=[25.]
# global_step=23254, episodic_return=[21.]
# SPS: 2506
# global_step=23345, episodic_return=[91.]
# global_step=23379, episodic_return=[34.]
# SPS: 2507
# global_step=23423, episodic_return=[44.]
# global_step=23479, episodic_return=[56.]
# SPS: 2508
# global_step=23515, episodic_return=[36.]
# global_step=23537, episodic_return=[22.]
# global_step=23572, episodic_return=[35.]
# global_step=23598, episodic_return=[26.]
# SPS: 2510
# global_step=23634, episodic_return=[36.]
# global_step=23646, episodic_return=[12.]
# global_step=23689, episodic_return=[43.]
# SPS: 2511
# global_step=23716, episodic_return=[27.]
# global_step=23742, episodic_return=[26.]
# SPS: 2513
# global_step=23815, episodic_return=[73.]
# global_step=23835, episodic_return=[20.]
# global_step=23867, episodic_return=[32.]
# SPS: 2513
# global_step=23902, episodic_return=[35.]
# global_step=23923, episodic_return=[21.]
# global_step=23936, episodic_return=[13.]
# global_step=23954, episodic_return=[18.]
# global_step=23977, episodic_return=[23.]
# global_step=23993, episodic_return=[16.]
# SPS: 2513
# global_step=24019, episodic_return=[26.]
# global_step=24036, episodic_return=[17.]
# global_step=24076, episodic_return=[40.]
# SPS: 2514
# global_step=24102, episodic_return=[26.]
# global_step=24123, episodic_return=[21.]
# global_step=24135, episodic_return=[12.]
# global_step=24155, episodic_return=[20.]
# global_step=24168, episodic_return=[13.]
# global_step=24199, episodic_return=[31.]
# SPS: 2514
# global_step=24234, episodic_return=[35.]
# global_step=24254, episodic_return=[20.]
# global_step=24268, episodic_return=[14.]
# SPS: 2515
# global_step=24323, episodic_return=[55.]
# global_step=24337, episodic_return=[14.]
# global_step=24378, episodic_return=[41.]
# global_step=24396, episodic_return=[18.]
# SPS: 2514
# global_step=24416, episodic_return=[20.]
# global_step=24466, episodic_return=[50.]
# SPS: 2515
# global_step=24503, episodic_return=[37.]
# global_step=24525, episodic_return=[22.]
# global_step=24545, episodic_return=[20.]
# global_step=24572, episodic_return=[27.]
# SPS: 2514
# global_step=24608, episodic_return=[36.]
# global_step=24620, episodic_return=[12.]
# global_step=24638, episodic_return=[18.]
# global_step=24695, episodic_return=[57.]
# SPS: 2515
# global_step=24708, episodic_return=[13.]
# global_step=24730, episodic_return=[22.]
# global_step=24744, episodic_return=[14.]
# global_step=24758, episodic_return=[14.]
# global_step=24776, episodic_return=[18.]
# global_step=24793, episodic_return=[17.]
# SPS: 2516
# global_step=24833, episodic_return=[40.]
# global_step=24873, episodic_return=[40.]
# global_step=24887, episodic_return=[14.]
# SPS: 2518
# global_step=24904, episodic_return=[17.]
# global_step=24944, episodic_return=[40.]
# global_step=24958, episodic_return=[14.]
# global_step=24970, episodic_return=[12.]
# global_step=24987, episodic_return=[17.]
# global_step=24998, episodic_return=[11.]
# SPS: 2519
# global_step=25024, episodic_return=[26.]
# global_step=25046, episodic_return=[22.]
# global_step=25066, episodic_return=[20.]
# global_step=25080, episodic_return=[14.]
# SPS: 2510
# global_step=25166, episodic_return=[86.]
# SPS: 2513
# global_step=25222, episodic_return=[56.]
# global_step=25247, episodic_return=[25.]
# global_step=25258, episodic_return=[11.]
# global_step=25282, episodic_return=[24.]
# SPS: 2514
# global_step=25302, episodic_return=[20.]
# global_step=25326, episodic_return=[24.]
# global_step=25356, episodic_return=[30.]
# SPS: 2516
# global_step=25413, episodic_return=[57.]
# global_step=25422, episodic_return=[9.]
# global_step=25438, episodic_return=[16.]
# global_step=25452, episodic_return=[14.]
# global_step=25481, episodic_return=[29.]
# SPS: 2518
# global_step=25509, episodic_return=[28.]
# global_step=25521, episodic_return=[12.]
# global_step=25586, episodic_return=[65.]
# SPS: 2519
# global_step=25601, episodic_return=[15.]
# global_step=25659, episodic_return=[58.]
# global_step=25686, episodic_return=[27.]
# SPS: 2520
# global_step=25729, episodic_return=[43.]
# global_step=25744, episodic_return=[15.]
# global_step=25758, episodic_return=[14.]
# global_step=25772, episodic_return=[14.]
# SPS: 2521
# global_step=25820, episodic_return=[48.]
# global_step=25849, episodic_return=[29.]
# global_step=25861, episodic_return=[12.]
# global_step=25879, episodic_return=[18.]
# global_step=25899, episodic_return=[20.]
# SPS: 2523
# global_step=25916, episodic_return=[17.]
# global_step=25945, episodic_return=[29.]
# SPS: 2525
# global_step=26010, episodic_return=[65.]
# global_step=26023, episodic_return=[13.]
# global_step=26033, episodic_return=[10.]
# global_step=26049, episodic_return=[16.]
# global_step=26064, episodic_return=[15.]
# global_step=26076, episodic_return=[12.]
# global_step=26091, episodic_return=[15.]
# SPS: 2526
# global_step=26116, episodic_return=[25.]
# global_step=26131, episodic_return=[15.]
# global_step=26162, episodic_return=[31.]
# global_step=26174, episodic_return=[12.]
# SPS: 2527
# global_step=26201, episodic_return=[27.]
# global_step=26227, episodic_return=[26.]
# global_step=26259, episodic_return=[32.]
# SPS: 2528
# global_step=26333, episodic_return=[74.]
# global_step=26354, episodic_return=[21.]
# SPS: 2530
# global_step=26405, episodic_return=[51.]
# global_step=26439, episodic_return=[34.]
# global_step=26453, episodic_return=[14.]
# global_step=26464, episodic_return=[11.]
# SPS: 2532
# global_step=26511, episodic_return=[47.]
# global_step=26540, episodic_return=[29.]
# global_step=26560, episodic_return=[20.]
# global_step=26578, episodic_return=[18.]
# SPS: 2532
# global_step=26605, episodic_return=[27.]
# global_step=26654, episodic_return=[49.]
# global_step=26676, episodic_return=[22.]
# SPS: 2534
# ...
# SPS: 2605
# SPS: 2605
# SPS: 2605
# SPS: 2605
# global_step=269697, episodic_return=[423.]
# SPS: 2605
# SPS: 2605
# SPS: 2605
# SPS: 2605
# SPS: 2605
# global_step=270197, episodic_return=[500.]
# SPS: 2605
# SPS: 2605
# SPS: 2604
# SPS: 2604
# SPS: 2604
# global_step=270697, episodic_return=[500.]
# SPS: 2604
# SPS: 2604
# SPS: 2604
# SPS: 2604
# SPS: 2604
# global_step=271197, episodic_return=[500.]
# SPS: 2604
# SPS: 2604
# SPS: 2604
# SPS: 2604
# SPS: 2604
# global_step=271697, episodic_return=[500.]
# SPS: 2603
# SPS: 2603
# SPS: 2603
# SPS: 2603
# SPS: 2603
# global_step=272197, episodic_return=[500.]
# SPS: 2603
# SPS: 2603
# SPS: 2603
# SPS: 2603
# SPS: 2603
# global_step=272697, episodic_return=[500.]
# SPS: 2603
# SPS: 2603
# SPS: 2602
# SPS: 2602
# SPS: 2602
# global_step=273197, episodic_return=[500.]
# SPS: 2602
# SPS: 2602
# SPS: 2602
# SPS: 2602
# SPS: 2602
# global_step=273697, episodic_return=[500.]
# SPS: 2602
# SPS: 2602
# SPS: 2602
# SPS: 2602
# global_step=274033, episodic_return=[336.]
# SPS: 2602
# SPS: 2601
# SPS: 2601
# SPS: 2601
# SPS: 2601
# global_step=274533, episodic_return=[500.]
# SPS: 2601
# SPS: 2601
# SPS: 2601
# SPS: 2601
# SPS: 2601
# global_step=275033, episodic_return=[500.]
# SPS: 2601
# SPS: 2600
# SPS: 2600
# SPS: 2600
# SPS: 2600
# global_step=275533, episodic_return=[500.]
# SPS: 2600
# SPS: 2600
# SPS: 2600
# SPS: 2600
# SPS: 2600
# global_step=276033, episodic_return=[500.]
# SPS: 2600
# SPS: 2600
# SPS: 2600
# SPS: 2600
# SPS: 2599
# global_step=276533, episodic_return=[500.]
# SPS: 2599
# SPS: 2599
# SPS: 2599
# SPS: 2599
# SPS: 2599
# global_step=277033, episodic_return=[500.]
# SPS: 2599
# SPS: 2599
# SPS: 2599
# SPS: 2599
# SPS: 2599
# global_step=277533, episodic_return=[500.]
# SPS: 2598
# SPS: 2598
# SPS: 2598
# SPS: 2598
# SPS: 2598
# global_step=278033, episodic_return=[500.]
# SPS: 2598
# SPS: 2598
# SPS: 2598
# SPS: 2598
# SPS: 2598
# global_step=278533, episodic_return=[500.]
# SPS: 2597
# SPS: 2597
# SPS: 2597
# SPS: 2597
# SPS: 2597
# global_step=279033, episodic_return=[500.]
# SPS: 2597
# SPS: 2597
# SPS: 2597
# SPS: 2597
# SPS: 2597
# global_step=279533, episodic_return=[500.]
# SPS: 2597
# SPS: 2597
# SPS: 2596
# SPS: 2596
# SPS: 2596
# global_step=280033, episodic_return=[500.]
# SPS: 2596
# SPS: 2596
# SPS: 2596
# global_step=280383, episodic_return=[350.]
# SPS: 2596
# SPS: 2596
# SPS: 2596
# SPS: 2596
# SPS: 2596
# global_step=280883, episodic_return=[500.]
# SPS: 2596
# SPS: 2596
# SPS: 2596
# SPS: 2596
# SPS: 2596
# global_step=281383, episodic_return=[500.]
# SPS: 2596
# SPS: 2596
# SPS: 2595
# SPS: 2595
# SPS: 2595
# global_step=281883, episodic_return=[500.]
# SPS: 2595
# SPS: 2595
# SPS: 2595
# SPS: 2595
# SPS: 2595
# global_step=282383, episodic_return=[500.]
# SPS: 2595
# SPS: 2595
# SPS: 2595
# SPS: 2595
# SPS: 2595
# global_step=282883, episodic_return=[500.]
# SPS: 2594
# SPS: 2594
# SPS: 2594
# SPS: 2594
# SPS: 2594
# global_step=283383, episodic_return=[500.]
# SPS: 2594
# SPS: 2594
# SPS: 2594
# SPS: 2594
# SPS: 2594
# global_step=283883, episodic_return=[500.]
# SPS: 2594
# SPS: 2594
# SPS: 2594
# SPS: 2593
# SPS: 2593
# global_step=284383, episodic_return=[500.]
# SPS: 2593
# SPS: 2593
# SPS: 2593
# SPS: 2593
# SPS: 2593
# global_step=284883, episodic_return=[500.]
# SPS: 2592
# SPS: 2592
# SPS: 2592
# SPS: 2592
# SPS: 2592
# global_step=285383, episodic_return=[500.]
# SPS: 2592
# SPS: 2592
# SPS: 2592
# SPS: 2592
# SPS: 2592
# global_step=285883, episodic_return=[500.]
# SPS: 2591
# SPS: 2591
# SPS: 2591
# SPS: 2591
# SPS: 2591
# global_step=286383, episodic_return=[500.]
# SPS: 2591
# SPS: 2591
# SPS: 2591
# SPS: 2591
# SPS: 2591
# global_step=286883, episodic_return=[500.]
# SPS: 2591
# SPS: 2591
# SPS: 2591
# SPS: 2591
# SPS: 2591
# global_step=287383, episodic_return=[500.]
# SPS: 2591
# SPS: 2590
# SPS: 2590
# SPS: 2590
# SPS: 2590
# global_step=287883, episodic_return=[500.]
# SPS: 2590
# SPS: 2590
# SPS: 2590
# SPS: 2590
# SPS: 2590
# global_step=288383, episodic_return=[500.]
# SPS: 2590
# SPS: 2590
# SPS: 2590
# SPS: 2590
# SPS: 2589
# global_step=288883, episodic_return=[500.]
# SPS: 2589
# SPS: 2589
# SPS: 2589
# SPS: 2589
# SPS: 2589
# global_step=289383, episodic_return=[500.]
# SPS: 2589
# SPS: 2589
# SPS: 2589
# SPS: 2589
# SPS: 2589
# global_step=289883, episodic_return=[500.]
# SPS: 2589
# SPS: 2589
# SPS: 2589
# SPS: 2589
# SPS: 2588
# global_step=290383, episodic_return=[500.]
# SPS: 2588
# SPS: 2588
# SPS: 2588
# SPS: 2588
# SPS: 2588
# global_step=290883, episodic_return=[500.]
# SPS: 2588
# SPS: 2588
# SPS: 2588
# SPS: 2588
# SPS: 2588
# global_step=291383, episodic_return=[500.]
# SPS: 2588
# SPS: 2587
# SPS: 2587
# SPS: 2587
# SPS: 2587
# global_step=291883, episodic_return=[500.]
# SPS: 2587
# SPS: 2587
# SPS: 2587
# SPS: 2587
# SPS: 2587
# global_step=292383, episodic_return=[500.]
# SPS: 2587
# SPS: 2587
# SPS: 2587
# SPS: 2586
# SPS: 2586
# global_step=292883, episodic_return=[500.]
# SPS: 2586
# SPS: 2586
# SPS: 2586
# SPS: 2586
# SPS: 2586
# global_step=293383, episodic_return=[500.]
# SPS: 2586
# SPS: 2586
# SPS: 2586
# SPS: 2586
# SPS: 2586
# global_step=293883, episodic_return=[500.]
# SPS: 2586
# SPS: 2586
# SPS: 2585
# SPS: 2585
# SPS: 2585
# global_step=294383, episodic_return=[500.]
# SPS: 2585
# SPS: 2585
# SPS: 2585
# SPS: 2585
# SPS: 2585
# global_step=294883, episodic_return=[500.]
# SPS: 2585
# SPS: 2585
# SPS: 2585
# SPS: 2585
# SPS: 2585
# global_step=295383, episodic_return=[500.]
# SPS: 2585
# SPS: 2585
# SPS: 2585
# SPS: 2585
# SPS: 2585
# global_step=295883, episodic_return=[500.]
# SPS: 2585
# SPS: 2584
# SPS: 2584
# SPS: 2584
# SPS: 2584
# global_step=296383, episodic_return=[500.]
# SPS: 2584
# SPS: 2584
# SPS: 2584
# SPS: 2584
# SPS: 2584
# global_step=296883, episodic_return=[500.]
# SPS: 2584
# SPS: 2584
# SPS: 2584
# SPS: 2584
# SPS: 2584
# global_step=297383, episodic_return=[500.]
# SPS: 2583
# SPS: 2583
# SPS: 2583
# SPS: 2583
# SPS: 2583
# global_step=297883, episodic_return=[500.]
# SPS: 2583
# SPS: 2583
# SPS: 2583
# SPS: 2583
# SPS: 2583
# global_step=298383, episodic_return=[500.]
# SPS: 2583
# SPS: 2583
# SPS: 2583
# SPS: 2582
# SPS: 2582
# global_step=298883, episodic_return=[500.]
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# global_step=299383, episodic_return=[500.]
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# global_step=299883, episodic_return=[500.]
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# global_step=300383, episodic_return=[500.]
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# SPS: 2582
# global_step=300883, episodic_return=[500.]
# SPS: 2582
# SPS: 2581
# SPS: 2581
# SPS: 2581
# SPS: 2581
# global_step=301383, episodic_return=[500.]
# SPS: 2581
# SPS: 2581
# SPS: 2581
# SPS: 2581
# SPS: 2581
# global_step=301883, episodic_return=[500.]
# SPS: 2581
# SPS: 2581
# SPS: 2580
# SPS: 2580
# SPS: 2580
# global_step=302383, episodic_return=[500.]
# SPS: 2580
# SPS: 2580
# SPS: 2580
# SPS: 2580
# SPS: 2580
# global_step=302883, episodic_return=[500.]
# SPS: 2580
# SPS: 2580
# SPS: 2580
# SPS: 2580
# SPS: 2580
# global_step=303383, episodic_return=[500.]
# SPS: 2580
# SPS: 2580
# SPS: 2580
# SPS: 2579
# SPS: 2579
# global_step=303883, episodic_return=[500.]
# SPS: 2579
# SPS: 2579
# SPS: 2579
# SPS: 2579
# SPS: 2579
# global_step=304383, episodic_return=[500.]
# SPS: 2579
# SPS: 2579
# SPS: 2578
# SPS: 2578
# SPS: 2578
# global_step=304883, episodic_return=[500.]
# SPS: 2578
# SPS: 2578
# SPS: 2578
# SPS: 2578
# SPS: 2578
# global_step=305383, episodic_return=[500.]
# SPS: 2578
# SPS: 2578
# SPS: 2578
# SPS: 2578
# SPS: 2578
# global_step=305883, episodic_return=[500.]
# SPS: 2578
# SPS: 2578
# SPS: 2578
# SPS: 2578
# SPS: 2578
# global_step=306383, episodic_return=[500.]
# SPS: 2578
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# global_step=306883, episodic_return=[500.]
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# global_step=307383, episodic_return=[500.]
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# global_step=307883, episodic_return=[500.]
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# SPS: 2577
# global_step=308383, episodic_return=[500.]
# SPS: 2576
# SPS: 2576
# SPS: 2576
# SPS: 2576
# SPS: 2576
# global_step=308883, episodic_return=[500.]
# SPS: 2576
# SPS: 2576
# SPS: 2576
# SPS: 2576
# SPS: 2576
# global_step=309383, episodic_return=[500.]
# SPS: 2576
# SPS: 2576
# SPS: 2576
# SPS: 2576
# SPS: 2576
# global_step=309883, episodic_return=[500.]
# SPS: 2575
# SPS: 2575
# SPS: 2575
# SPS: 2575
# SPS: 2575
# global_step=310383, episodic_return=[500.]
# SPS: 2575
# SPS: 2575
# SPS: 2575
# SPS: 2575
# SPS: 2575
# global_step=310883, episodic_return=[500.]
# SPS: 2575
# SPS: 2575
# SPS: 2575
# SPS: 2575
# SPS: 2575
# global_step=311383, episodic_return=[500.]
# SPS: 2575
# SPS: 2575
# SPS: 2574
# SPS: 2574
# SPS: 2574
# global_step=311883, episodic_return=[500.]
# SPS: 2574
# SPS: 2574
# SPS: 2574
# SPS: 2574
# SPS: 2574
# global_step=312383, episodic_return=[500.]
# SPS: 2574
# SPS: 2574
# SPS: 2574
# SPS: 2574
# SPS: 2574
# global_step=312883, episodic_return=[500.]
# SPS: 2574
# SPS: 2574
# SPS: 2574
# SPS: 2574
# SPS: 2574
# global_step=313383, episodic_return=[500.]
# SPS: 2573
# SPS: 2573
# SPS: 2573
# SPS: 2573
# SPS: 2573
# global_step=313883, episodic_return=[500.]
# SPS: 2573
# SPS: 2573
# SPS: 2573
# SPS: 2573
# SPS: 2573
# global_step=314383, episodic_return=[500.]
# SPS: 2573
# SPS: 2573
# SPS: 2573
# SPS: 2573
# SPS: 2573
# global_step=314883, episodic_return=[500.]
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2572
# global_step=315383, episodic_return=[500.]
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2572
# global_step=315883, episodic_return=[500.]
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2572
# global_step=316383, episodic_return=[500.]
# SPS: 2572
# SPS: 2572
# SPS: 2572
# SPS: 2571
# SPS: 2571
# global_step=316883, episodic_return=[500.]
# SPS: 2571
# SPS: 2571
# SPS: 2571
# SPS: 2571
# SPS: 2571
# global_step=317383, episodic_return=[500.]
# SPS: 2571
# SPS: 2571
# SPS: 2571
# SPS: 2571
# SPS: 2571
# global_step=317883, episodic_return=[500.]
# SPS: 2571
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# global_step=318383, episodic_return=[500.]
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# global_step=318883, episodic_return=[500.]
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# global_step=319383, episodic_return=[500.]
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# SPS: 2570
# global_step=319883, episodic_return=[500.]
# SPS: 2569
# SPS: 2569
# SPS: 2569
# SPS: 2569
# SPS: 2569
# global_step=320383, episodic_return=[500.]
# SPS: 2569
# SPS: 2569
# SPS: 2569
# SPS: 2569
# SPS: 2569
# global_step=320883, episodic_return=[500.]
# SPS: 2569
# SPS: 2569
# SPS: 2569
# SPS: 2569
# SPS: 2569
# global_step=321383, episodic_return=[500.]
# SPS: 2568
# SPS: 2568
# SPS: 2568
# SPS: 2568
# SPS: 2568
# global_step=321883, episodic_return=[500.]
# SPS: 2568
# SPS: 2568
# SPS: 2568
# SPS: 2568
# SPS: 2568
# global_step=322383, episodic_return=[500.]
# SPS: 2568
# SPS: 2568
# SPS: 2568
# SPS: 2567
# SPS: 2567
# global_step=322883, episodic_return=[500.]
# SPS: 2567
# SPS: 2567
# SPS: 2567
# SPS: 2567
# SPS: 2567
# global_step=323383, episodic_return=[500.]
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# global_step=323883, episodic_return=[500.]
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# global_step=324383, episodic_return=[500.]
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# global_step=324883, episodic_return=[500.]
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# SPS: 2566
# global_step=325383, episodic_return=[500.]
# SPS: 2566
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# global_step=325883, episodic_return=[500.]
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# global_step=326383, episodic_return=[500.]
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# global_step=326883, episodic_return=[500.]
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# SPS: 2565
# global_step=327383, episodic_return=[500.]
# SPS: 2565
# SPS: 2565
# SPS: 2564
# SPS: 2564
# SPS: 2564
# global_step=327883, episodic_return=[500.]
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# global_step=328383, episodic_return=[500.]
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# global_step=328883, episodic_return=[500.]
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# global_step=329383, episodic_return=[500.]
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# SPS: 2564
# global_step=329883, episodic_return=[500.]
# SPS: 2564
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# global_step=330383, episodic_return=[500.]
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# global_step=330883, episodic_return=[500.]
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# global_step=331383, episodic_return=[500.]
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# SPS: 2563
# global_step=331883, episodic_return=[500.]
# SPS: 2563
# SPS: 2563
# SPS: 2562
# SPS: 2562
# SPS: 2562
# global_step=332383, episodic_return=[500.]
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# global_step=332883, episodic_return=[500.]
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# global_step=333383, episodic_return=[500.]
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# global_step=333883, episodic_return=[500.]
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# SPS: 2562
# global_step=334383, episodic_return=[500.]
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# global_step=334883, episodic_return=[500.]
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# global_step=335383, episodic_return=[500.]
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# global_step=335883, episodic_return=[500.]
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# global_step=336383, episodic_return=[500.]
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# SPS: 2561
# global_step=336883, episodic_return=[500.]
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# global_step=337383, episodic_return=[500.]
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# global_step=337883, episodic_return=[500.]
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# global_step=338383, episodic_return=[500.]
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# SPS: 2560
# global_step=338883, episodic_return=[500.]
# SPS: 2559
# SPS: 2559
# SPS: 2559
# SPS: 2559
# SPS: 2559
# global_step=339383, episodic_return=[500.]
# SPS: 2557
# SPS: 2557
# SPS: 2557
# SPS: 2557
# SPS: 2556
# global_step=339883, episodic_return=[500.]
# SPS: 2556
# SPS: 2556
# SPS: 2556
# SPS: 2556
# SPS: 2556
# global_step=340383, episodic_return=[500.]
# SPS: 2556
# SPS: 2555
# SPS: 2555
# SPS: 2555
# SPS: 2555
# global_step=340883, episodic_return=[500.]
# SPS: 2555
# SPS: 2555
# SPS: 2555
# SPS: 2555
# SPS: 2555
# global_step=341383, episodic_return=[500.]
# SPS: 2555
# SPS: 2554
# SPS: 2554
# SPS: 2554
# SPS: 2554
# global_step=341883, episodic_return=[500.]
# SPS: 2554
# SPS: 2554
# SPS: 2554
# SPS: 2554
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/8m/r3kmm3xs1lngf9bhwg216mlc0000gn/T/ipykernel_38286/1592885407.py in <module>
#      38                 target_max, _ = target_network(data.next_observations).max(dim=1)
#      39                 td_target = data.rewards.flatten() + args.gamma * target_max * (1 - data.dones.flatten())
# ---> 40             old_val = q_network(data.observations).gather(1, data.actions).squeeze()
#      41             loss = F.mse_loss(td_target, old_val)
#      42
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /var/folders/8m/r3kmm3xs1lngf9bhwg216mlc0000gn/T/ipykernel_38286/3035537976.py in forward(self, x)
#     100
#     101     def forward(self, x):
# --> 102         return self.network(x)
#     103
#     104
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1493
#    1494     def _call_impl(self, *args, **kwargs):
# -> 1495         forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1496         # If we don't have any hooks, we want to skip the rest of the logic in
#    1497         # this function, and just call forward.
#
# KeyboardInterrupt:
